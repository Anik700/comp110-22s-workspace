# %% [markdown]
# # Analysis for Continuous Improvement
#
# Author Name: Aniketh Hongalgi
#
# 9-digit PID: 730243145
#
# Continuous Improvement embraces a belief there is _always room to make things better_. It is a mindset and process we value and practice in this course. In this assignment, you are able to practice continuous improvement and contribute to the design ideas of the course.
#
# ## Brainstorming Ideas
#
# Reflect on your personal experiences and observations in COMP110 and **brainstorm modifications to the course that _create value_ beyond its current design**. When brainstorming, try not to be critical of the ideas you come up with regarding scale, stakeholders impacted, or for any other reasons. In the markdown cell below, brainstorm 3 to 5 ideas you think would create value for you.
#
# Each brainstormed idea should state a. the suggested change or addition, b. what the expected value created, and c. which specific stakeholders would benefit.  If helpful, expand on the following template "The course should (state idea here) because it will (state value created here) for (insert stakeholders here)."
#
# Example A: "The course should use only examples from psychology experiments because it will be more relevant for students who are psychology majors."
#
# Example B: "The course should not have post-lesson questions because they are not useful for most students in the class."

# %% [markdown]
# ### Part 1. Creative Ideation
#
# 1. The course should have better, more descriptive feedback to errors that may arise from gradescope exercise tests because it will reduce office hours visits and save time for students enrolled in the course.
# 2. The course could have small groups within the class to help students learn from one another and approach each other for feedback and help.
# 3. The course could have an end of semester project that provides some benefit to a business or the school because it would help prepare students for a career in computer science while providing a service to the community/society.
# 4. The course could include a group project where the students are asked to provide a benefit to a community, business, school, etc. This would add to the prestigous.
# 5. The course could have more detailed instructions in the write-ups to provide students more structured instruction that could teach them how to approach or think about a computer science problem.

# %% [markdown]
# ## Connecting with Available Data
#
# The data you have available for this analysis is limited to the anonymized course survey you and your peers filled out a few weeks ago. The data is found in the `survey.csv` file in this exercise directory. Each row represents an individual survey response. Each column has a description which can be found on the project write-up here: <https://22s.comp110.com/exercises/ex08.html>
#
# Review the list of available data and identify which one of your ideas _does not_, or is _least likely to_, have relevant data to support the analysis of your idea to create value. In the box below, identify which of your ideas lacks data and suggest how we might be able to collect this data in the future. One aspect of _continuous improvement_ is trying to avoid "tunnel vision" where possible improvements are not considered because there is no data available to analyze it. Identifying new data sources can unlock improvements!

# %% [markdown]
# ### Part 2. Identifying Missing Data
#
# 1. Idea without sufficient data to analyze: The group project ideas(3 and 4) would have insufficient data because there are very few students who have applied their skills from just COMP 110 to projects outside class and of those students who have, they will likely not remember or have data for us to analyze. However, we could analyze how much publicity or revenue the university/business recieved from the project.
#
# 2. Suggestion for how to collect data to support this idea in the future: Ask students who do participate in projects outside of class that pertain mostly to COMP 110 to complete a survey to collect data on whether having a class project would be an effective use of class time. We could also collect data on revenues and publicity from the businesses or university that benefits from the project.

# %% [markdown]
# ## Choosing an Idea to Analyze
#
# Consider those of your ideas which _do_ seem likely to have relevant data to analyze. If none of your ideas do, spend a few minutes and brainstorm another idea or two with the added connection of data available on hand and add those ideas to your brainstormed ideas list.
#
# Select the one idea which you believe is _most valuable_ to analyze relative to the others and has data to support the analysis of. In the markdown cell for Part 3 below, identify the idea you are exploring and articulate why you believe it is most valuable (e.g. widest impact, biggest opportunity for improvement, simplest change for significant improvement, and so on).

# %% [markdown]
# ### Part 3. Choosing Your Analysis
#
# 1. Idea to analyze with available data: The course could have more detailed instructions in the write-ups to provide students more structured instruction that could teach them how to approach or think about a computer science problem.
#
# 2. This idea is more valuable than the others brainstormed because: It is more reasonable to achieve and there is more data that is applicable to this idea than the other ones.

# %% [markdown]
# ## Your Analysis
#
# Before you begin analysis, a reminder that we do not expect the data to support everyone's ideas and you can complete this exercise for full credit even if the data does not clearly support your suggestion or even completely refutes it. What we are looking for is a logical attempt to explore the data using the techniques you have learned up until now in a way that _either_ supports, refutes, or does not have a clear result and then to reflect on your findings after the analysis.
#
# Using the utility functions you created for the previous exercise, you will continue with your analysis in the following part. Before you begin, refer to the rubric on the technical expectations of this section in the exercise write-up.
#
# In this section, you are expected to interleave code and markdown cells such that for each step of your analysis you are starting with an English description of what you are planning to do next in a markdown cell, followed by a Python cell that performs that step of the analysis.

# %% [markdown]
# ### Part 4. Analysis
#
# We begin by changing some settings in the notebook to automatically reload changes to imported files.

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# We continue by importing the helper functions from `data_utils`.

# %%
from data_utils import read_csv_rows
from data_utils import columnar
from data_utils import head
from data_utils import select
from data_utils import count

# %% [markdown]
# Next, ... (you take it from here and add additional code and markdown cells to read in the CSV file and process it as needed)

# %%
SURVEY_DATA_CSV_FILE_PATH: str = "../../data/survey.csv"
DATA_FILE_PATH=f"../../data/survey.csv"

# %% [markdown]
# First, save the survey data as a dataframe and apply the head function to see the first few rows of data.

# %%
data_rows: list[dict[str, str]] = read_csv_rows(DATA_FILE_PATH)
# data_head = head(columnar(data_rows), 5)
data_head = columnar(data_rows)
head(data_head, 5)
# Out:
# {'row': ['0', '1', '2', '3', '4'],
#  'year': ['22', '25', '25', '24', '25'],
#  'unc_status': ['Returning UNC Student',
#   'Returning UNC Student',
#   'Incoming First-year Student',
#   'Returning UNC Student',
#   'Incoming First-year Student'],
#  'comp_major': ['No', 'No', 'Yes - BA', 'Yes - BS', 'Yes - BA'],
#  'primary_major': ['Mathematics',
#   'Mathematics',
#   'Computer Science',
#   'Computer Science',
#   'Computer Science'],
#  'data_science': ['No', 'Yes', 'No', 'Maybe', 'No'],
#  'prereqs': ['MATH 233, MATH 347, MATH 381',
#   'MATH 130, MATH 231, STOR 155',
#   'MATH 130, MATH 152, MATH 210',
#   'MATH 231, MATH 232, STOR 155',
#   'MATH 130'],
#  'prior_exp': ['7-12 months',
#   'None to less than one month!',
#   'None to less than one month!',
#   '2-6 months',
#   'None to less than one month!'],
#  'ap_principles': ['No', '', '', 'No', ''],
#  'ap_a': ['No', '', '', 'No', ''],
#  'other_comp': ['UNC', '', '', 'High school course (IB or other)', ''],
# ...

# %% [markdown]
# Next, use the select function to highlight the columns of data you want to use in your analysis.

# %%
new_list: list[str] = ['prior_exp', 'difficulty', 'understanding', 'programming_effective']
select(data_head, new_list)
# Out:
# {'prior_exp': ['7-12 months',
#   'None to less than one month!',
#   'None to less than one month!',
#   '2-6 months',
#   'None to less than one month!',
#   '2-6 months',
#   '2-6 months',
#   'None to less than one month!',
#   'None to less than one month!',
#   'None to less than one month!',
#   '2-6 months',
#   '2-6 months',
#   'None to less than one month!',
#   '2-6 months',
#   'None to less than one month!',
#   '2-6 months',
#   'None to less than one month!',
#   '1-2 years',
#   'None to less than one month!',
#   'None to less than one month!',
#   'None to less than one month!',
#   'None to less than one month!',
#   '2-6 months',
#   'None to less than one month!',
#   'None to less than one month!',
#   'None to less than one month!',
#   'None to less than one month!',
#   'None to less than one month!',
#   '7-12 months',
#   'None to less than one month!',
#   'None to less than one month!',
#   'None to less than one month!',
# ...

# %% [markdown]
# Use matplotlib to graph the data highlighted from the previous step.

# %%
transposed = columnar(data_rows)
diff_counts = count(transposed['difficulty'])
prior_counts = count(transposed['understanding'])
from matplotlib import pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
fig.suptitle("COMP 110 Class Survey Results")


axes[0].set_title("By Difficulty")
axes[0].bar(diff_counts.keys(), diff_counts.values())
axes[0].tick_params(axis='x', labelrotation = 45)

axes[1].set_title("By Understanding")
axes[1].bar(prior_counts.keys(), prior_counts.values())
# Out:
# <BarContainer object of 7 artists>

# %%
from data_utils import avg
transposed = columnar(data_rows)
diff_counts = count(transposed['prior_exp'])
prior_counts = count(transposed['programming_effective'])
from matplotlib import pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
fig.suptitle("COMP 110 Class Survey Results 2")


axes[0].set_title("Prior Experience")
axes[0].bar(diff_counts.keys(), diff_counts.values())
axes[0].tick_params(axis='x', labelrotation = 45)

axes[1].set_title("Effectiveness of Programming Exercises")
axes[1].bar(prior_counts.keys(), prior_counts.values())
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# Next, I wanted to calculate the average of the responses to the difficulty question. This would help me understand how difficult students percieved the class on average. In order to calculate the average, I had to first convert the dict[str, list[str]] of responses to a list[int].

# %% [markdown]
# I started by isolating the number of responses for each answer choice by using the select and count functions.

# %%
diff_dict = select(data_head,['programming_effective'])
count_dict = count(diff_dict['programming_effective'])
count1 = count_dict["1"]
count2 = count_dict["2"]
count3 = count_dict["3"]
count4 = count_dict["4"]
count5 = count_dict["5"]
count6 = count_dict["6"]
count7 = count_dict["7"]
count_dict
# Out:
# {'7': 324, '5': 82, '6': 154, '4': 34, '2': 11, '3': 10, '1': 5}

# %% [markdown]
# I calculated the total number of responses for the difficulty question by applying the summate helper function to the variable count_dict.

# %%
from data_utils import summate
summate(count_dict)
# Out:
# 620

# %% [markdown]
# I then multiplied the number of responses for each difficulty score by their responses (ex: if 50 people responded '6' to the question, then 50 * 6)

# %%
# Multiply the count fns by their value (ie count 1 * 1)
multi1 = count_dict["1"] * 1
multi2 = count_dict["2"] * 2
multi3 = count_dict["3"] * 3
multi4 = count_dict["4"] * 4
multi5 = count_dict["5"] * 5
multi6 = count_dict["6"] * 6
multi7 = count_dict["7"] * 7

# %% [markdown]
# I then created a variable named diff_sum which was the summation of all the multi variables created prior. I then divided diff_sum by the number of responses calculated by summate to get the average score for the programming exercises question.

# %%
program_sum = multi1 + multi2 + multi3 + multi4 + multi5 + multi6 + multi7
program_average = diff_sum/620
program_average
# Out:
# 4.383870967741935

# %% [markdown]
# The average response to the difficulty question was 4.38.

# %% [markdown]
# ## Conclusion
#
# In the following markdown cell, write a reflective conclusion given the analysis you performed and identify recommendations.
#
# If your analysis of the data supports your idea, state your recommendation for the change and summarize the data analysys results you found which support it. Additionally, describe any extensions or refinements to this idea which might be explored further. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change.
#
# If your analysis of the data is inconclusive, summarize why your data analysis results were inconclusive in the support of your idea. Additionally, describe what experimental idea implementation or additional data collection might help build more confidence in assessing your idea. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by experimenting with your idea.
#
# Finally, if your analysis of the data does not support it, summarize your data analysis results and why it refutes your idea. Discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change. If you disagree with the validity of the findings, describe why your idea still makes sense to implement and what alternative data would better support it. If you agree with the validity of the data analysis, describe what alternate ideas or extensions you would explore instead.

# %% [markdown]
# ### Part 5. Conclusion

# %% [markdown]
# The analysis conducted does support my original belief that students would benefit from more clear, step-by-step instruction on exercise assignments. A majority of students have less than a month or no coding experience, which suggests they are developing their coding thought-process from scratch and likely need more instruction that students who do have some background in coding. Surprisingly the difficulty responses were relatively low with most scores being between 4 and 5. A majority of students also rated their level of understanding between 5 and 6, which suggests that they are able to understand course instruction relatively easily. The final part of the analysis was to calculate the average score from the 'programming_effective' question. The average response was 4.38 which suggests that most people felt that the programming exercises were not as effective at teaching the material as maybe the instructors would have hoped.
#
# More research is needed to truly understand whether the results of this brief analysis are accurate or due to chance. For example, we need to compute correlational statistics to measure the strength of the relationship between the responses and the grades/performance of the class. We could also ask more specific questions on the difficutly of the exercises such as "Was attending office hours helpful?" or "Do you like exercises where you are given more detailed instruction or less instruction?".
#
# The trade-off for providing more clear, step-by-step instructions on the programming exercises would be that instructors and staff would likely have to spend more time writing up the exercise instructions. It would also prevent students from using their imagination and critical thinking skills effectively to solve problems on their own. However, it would improve the effiency to which a student can complete the assignment and reduce the number of office hour visits. It would also provide more structured guidance to help a student think like a programmer.
